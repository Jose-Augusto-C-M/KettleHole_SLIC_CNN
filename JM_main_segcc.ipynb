# %% [markdown]
# <a href="https://colab.research.google.com/github/Jose-Augusto-C-M/KettleHole_SLIC_CNN/blob/main/JM_main_segcc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras import applications 
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Model, load_model
from numpy import resize, expand_dims
from keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
from keras import backend as K
import glob
from skimage import segmentation
from skimage.segmentation import mark_boundaries
from skimage.util import img_as_float, img_as_ubyte
import tensorflow as tf
from skimage import io
import numpy as np
from skimage.util import img_as_float, img_as_ubyte
from PIL import Image
from numpy import resize, expand_dims
from IPython.display import HTML, display
from keras.preprocessing.image import ImageDataGenerator
import pylab
from tqdm import tqdm
import time
import csv
import os
import functools
import multiprocessing
from multiprocessing import Process, Manager
import threading
import tensorflow as tf
import matplotlib.image as mpimg

# %%
def synchronized(wrapped):
    lock = threading.Lock()
    @functools.wraps(wrapped)
    def _wrap(*args, **kwargs):
        with lock:
            return wrapped(*args, **kwargs)
    return _wrap
class Classfield_segmented(object):
       c = csv.writer(open("dados.csv", "w", newline=''))
       location_drive='*' #Location for the base of the folders in the drive
       IMG_WIDTH, IMG_HEIGHT = 224,224
       dict_classes=['background','Cirsium_arvense','Salix spec','Oenanthe aquatica','Phalaris arundinacea','Urtica dioica','Arctium spec.','Carex riparia live','Salix cinerea','Typha live', 'Phragmites australis live','Phragmites australis mix live and dead','Nymphaeidae','water']
       color_classes=[(0, 0, 0),(255,192,203),(200, 200, 74 ),(200, 190, 167),(200, 137, 118),(62, 200, 41),(200, 37, 168),(146, 200, 7),(200, 179, 37),(165, 200, 48),(200, 148, 179),(200, 167, 193),(200, 107, 163),(122, 144, 200 )]
       model=None  
       
       def getRAMinfo(self):
         p = os.popen('free')
         i = 0
         while 1:
            i = i + 1
            line = p.readline()
            if i==2:
              return(line.split()[1:4])
              
       @synchronized
       
       def predict(self,image):
          predict=self.model.predict(image)

          

          return np.argmax(predict, axis=1)
          
       def job_process(self,model_name,filename, preprocess_input, decode_predictions,list_iou):
            print(filename)
            im=io.imread(filename)
            #plt.imshow(im)
            
            #plt.show()
            
            #Create SLIC

            img_load=im.copy()
            ##create a superpixels
            segments = segmentation.slic(img_load, n_segments=1000,compactness=10, sigma=5)
            # segments = img_load
            #mark boundaries
            img_slic=mark_boundaries(img_load, segments)
            
            mpimg.imsave(self.location_drive + "result/"+model_name+"/slic/"+filename.split("image/")[1],img_slic) #local do drive

            #Classificando os superpixels
            #print(segments)
            #superpixels=[]
            pred_list=[]
            qtd=len(np.unique(segments))
            print("Processando os superpixels da imagem")
            img_paint=im.copy()    
            for (i, seg) in tqdm(enumerate(np.unique(segments )), desc = 'tqdm() Progress Bar Segments'):
              # Create a mask, painting black all pixels outside of segment and white the pixels inside.
              mask_segment = np.zeros(  img_load.copy().shape[:2], dtype="uint8")
              mask_segment[segments == seg] = 255

              size_segment = mask_segment[segments == seg].size
              segment =  img_load.copy() 
              segment = cv2.bitwise_and(segment, segment, mask=mask_segment)
              # Get the countours around the segment
              contours, _  = cv2.findContours(mask_segment,cv2.RETR_LIST,cv2.CHAIN_APPROX_SIMPLE)[-2:]
         
              m = -1
              max_contour = None
              for cnt in contours:
                       if (len(cnt) > m):
                          m = len(cnt)
                          max_contour = cnt

              # Get the rectangle that encompasses the countour
              x,y,w,h = cv2.boundingRect(max_contour)
              segment = segment[y:y+h, x:x+w]

              #superpixels.append(segment)
         
              # pre-process the image for classification
              image = cv2.resize(segment, (self.IMG_HEIGHT, self.IMG_WIDTH))
              image = image.astype("float") / 255.0
              image = img_to_array(image)
              image = np.expand_dims(image, axis=0)
           
              predict = self.predict(image)
              
              color=None

                 
              for cont, name_classs in enumerate(self.dict_classes):  
                if(self.dict_classes[predict[0]]==name_classs):
                    color=self.color_classes[cont]
                    break
              #predict = np.argmax(predict, axis=1)
              #print(predict)
              pred_list.append(self.dict_classes[predict[0]])
              #if(idx_segment<4):
                #plt.imshow(segment)
                #print(dict_classes[predict[0]])
                #plt.show()
                #break
              
              #painting  
              height, width, channels = img_paint.shape   
               
              mask_inv = cv2.bitwise_not(mask_segment)
               
              # Paint all pixels in original image with choosed color
              class_color = np.zeros((height,width,3), np.uint8)
              class_color[:, :] = color
              colored_image = cv2.addWeighted(img_paint, 0.0, class_color, 1.0, 0)
               
              colored_image = cv2.bitwise_and(colored_image, colored_image, mask=mask_segment)
              clear = False
              # Create a new image keeping the painting only in pixels inside of segments
              new_image =   img_paint
              new_image = cv2.bitwise_and(new_image, new_image, mask=mask_inv)
              mask_segment[:] = 255
              img_paint = cv2.bitwise_or(new_image, colored_image, mask=mask_segment)
               
             
            mpimg.imsave(self.location_drive + "result/"+model_name+"/paint/"+filename.split("image/")[1],img_paint) #location for the segmented image in the drive
            ##Calcula o IoU
                
       def process(self):       
              dict_preprocessing = {}
              dict_preprocessing[1] = applications.vgg16.preprocess_input, applications.vgg16.decode_predictions
              dict_preprocessing[2] = applications.inception_v3.preprocess_input, applications.inception_v3.decode_predictions
              dict_preprocessing[3] = applications.densenet.preprocess_input, applications.densenet.decode_predictions
              dict_preprocessing[4] = applications.resnet_v2.preprocess_input, applications.resnet_v2.decode_predictions
              dict_preprocessing[5] = applications.xception.preprocess_input, applications.xception.decode_predictions

            

              self.c.writerow(["Modelo","Arquivo","IOU"])
              #names of models
              list_model=["Xception"]#,"ResNet152V2" , "InceptionV3","VGG16", "DenseNet201"] # this command loads the Trained weights
              for model_name in tqdm(list_model, desc = 'tqdm() Progress Bar Models'):
                K.clear_session()
                self.model = load_model(self.location_drive+"model/"+model_name+"_transfer_learning_adagrad.h5")


                

                preprocess_input=None
                decode_predictions=None
                if model_name=="VGG16":
                   preprocess_input, decode_predictions = dict_preprocessing[1]
                if model_name=="InceptionV3":
                   preprocess_input, decode_predictions = dict_preprocessing[2]
                if model_name=="DenseNet201":
                   preprocess_input, decode_predictions = dict_preprocessing[3]
                if model_name=="ResNet152V2":
                   preprocess_input, decode_predictions = dict_preprocessing[4]
                if model_name=="Xception":
                   preprocess_input, decode_predictions = dict_preprocessing[5]   
                list_iou=[]
                print("Load Model H5:"+model_name+"_transfer_learning_adagrad.h5")
                #Process each image
                threads=[]
                for filename in tqdm(glob.iglob(self.location_drive+'image/*.png', recursive=True), desc = 'tqdm() Progress Bar Files'):
                   self.job_process(model_name,filename,preprocess_input, decode_predictions,list_iou)
                   #th = threading.Thread(target=self.job_process,args=(model_name,filename,preprocess_input, decode_predictions,list_iou ))
                   #threads.append(th)
                
                # Output is in kb, here I convert it in Mb for readability
                RAM_stats = self.getRAMinfo()
                RAM_total = round(int(RAM_stats[0]) / 1000,1)
                RAM_used = round(int(RAM_stats[1]) / 1000,1)
                print("RAM Total : "+str(RAM_total))
                print("RAM Used : "+str(RAM_used))
                 
                print("Wait a moment, the threads are processing "+str(len(threads)) +" images, it may be delayed depending on the size or quantity of the images!")
                with tqdm(total=len(threads)) as pbar:
                  for  t in threads:
                        t.start()
                        #t.join()
                        if((RAM_total)<33000):#se menor que 10gb
                             RAM_stats = self.getRAMinfo()
                             RAM_used = round(int(RAM_stats[1]) / 1000,1)
                             if((RAM_total-RAM_used)<6000):
                               t.join()
                             pbar.update(1)
                  pbar.close()
                for  t in threads:
                   t.join()
                #print("Average IoU"+ str(np.mean(list_iou)))
                #print("Model_name:"+list_iou)

                return dict_preprocessing[5]
                return list_iou
                return threads

if __name__ == "__main__":
    process_file= Classfield_segmented()
    process_file.process()
# Out:
# tqdm() Progress Bar Models:   0%|          | 0/1 [00:00<?, ?it/s]
# Load Model H5:Xception_transfer_learning_adagrad.h5
# tqdm() Progress Bar Files: 0it [00:00, ?it/s]
# /content/drive/MyDrive/dataset_anette/data_labelme/image/100_0002_0033.png
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: FutureWarning: skimage.measure.label's indexing starts from 0. In future version it will start from 1. To disable this warning, explicitely set the `start_label` parameter to 1.
# Processando os superpixels da imagem
# tqdm() Progress Bar Segments: 0it [00:00, ?it/s]
#
# tqdm() Progress Bar Segments: 1it [00:10, 10.90s/it]
#
# tqdm() Progress Bar Segments: 2it [00:11,  4.77s/it]
#
# tqdm() Progress Bar Segments: 3it [00:11,  2.81s/it]
#
# tqdm() Progress Bar Segments: 4it [00:12,  1.88s/it]
#
# tqdm() Progress Bar Segments: 5it [00:12,  1.43s/it]
#
# tqdm() Progress Bar Segments: 6it [00:13,  1.10s/it]
#
# tqdm() Progress Bar Segments: 7it [00:13,  1.11it/s]
#
# tqdm() Progress Bar Segments: 8it [00:14,  1.31it/s]
#
# tqdm() Progress Bar Segments: 9it [00:14,  1.47it/s]
#
# tqdm() Progress Bar Segments: 10it [00:15,  1.63it/s]
#
# tqdm() Progress Bar Segments: 11it [00:15,  1.75it/s]
#
# tqdm() Progress Bar Segments: 12it [00:16,  1.85it/s]
#
# tqdm() Progress Bar Segments: 13it [00:16,  1.92it/s]
#
# tqdm() Progress Bar Segments: 14it [00:17,  1.98it/s]
#
# tqdm() Progress Bar Segments: 15it [00:17,  2.01it/s]
#
# tqdm() Progress Bar Segments: 16it [00:18,  2.05it/s]
#
# tqdm() Progress Bar Segments: 17it [00:18,  2.05it/s]
#
# tqdm() Progress Bar Segments: 18it [00:19,  2.07it/s]
#
# tqdm() Progress Bar Segments: 19it [00:19,  2.09it/s]
#
# tqdm() Progress Bar Segments: 20it [00:20,  2.09it/s]
#
# tqdm() Progress Bar Segments: 21it [00:20,  2.09it/s]
#
# tqdm() Progress Bar Segments: 22it [00:21,  2.09it/s]
#
# tqdm() Progress Bar Segments: 23it [00:21,  2.09it/s]
#
# tqdm() Progress Bar Segments: 24it [00:22,  2.08it/s]
#
# tqdm() Progress Bar Segments: 25it [00:22,  2.08it/s]
#
# tqdm() Progress Bar Segments: 26it [00:22,  2.06it/s]
#
# tqdm() Progress Bar Segments: 27it [00:23,  2.08it/s]
#
# tqdm() Progress Bar Segments: 28it [00:23,  2.08it/s]
#
# tqdm() Progress Bar Segments: 29it [00:24,  2.10it/s]
#
# tqdm() Progress Bar Segments: 30it [00:24,  2.09it/s]
#
# tqdm() Progress Bar Segments: 31it [00:25,  2.10it/s]
#
# tqdm() Progress Bar Segments: 32it [00:25,  2.10it/s]
#
# tqdm() Progress Bar Segments: 33it [00:26,  2.11it/s]
#
# tqdm() Progress Bar Segments: 34it [00:26,  2.12it/s]
#
# tqdm() Progress Bar Segments: 35it [00:27,  2.09it/s]
#
# tqdm() Progress Bar Segments: 36it [00:27,  2.10it/s]
#
# tqdm() Progress Bar Segments: 37it [00:28,  2.09it/s]
#
# tqdm() Progress Bar Segments: 38it [00:28,  2.10it/s]
#
# tqdm() Progress Bar Segments: 39it [00:29,  2.08it/s]
#
# tqdm() Progress Bar Segments: 40it [00:29,  2.10it/s]
#
# tqdm() Progress Bar Segments: 41it [00:30,  2.09it/s]
#
# tqdm() Progress Bar Segments: 42it [00:30,  2.09it/s]
#
# tqdm() Progress Bar Segments: 43it [00:31,  2.10it/s]
#
# tqdm() Progress Bar Segments: 44it [00:31,  2.10it/s]
#
# tqdm() Progress Bar Segments: 45it [00:32,  2.09it/s]
#
# tqdm() Progress Bar Segments: 46it [00:32,  2.11it/s]
#
# tqdm() Progress Bar Segments: 47it [00:32,  2.10it/s]
#
# tqdm() Progress Bar Segments: 48it [00:33,  2.11it/s]
#
# tqdm() Progress Bar Segments: 49it [00:33,  2.11it/s]
#
# tqdm() Progress Bar Segments: 50it [00:34,  2.10it/s]
#
# tqdm() Progress Bar Segments: 51it [00:34,  2.10it/s]
#
# tqdm() Progress Bar Segments: 52it [00:35,  2.10it/s]
#
# tqdm() Progress Bar Segments: 53it [00:35,  2.11it/s]
#
# tqdm() Progress Bar Segments: 54it [00:36,  2.09it/s]
#
# tqdm() Progress Bar Segments: 55it [00:36,  2.09it/s]
#
# tqdm() Progress Bar Segments: 56it [00:37,  2.09it/s]
#
# tqdm() Progress Bar Segments: 57it [00:37,  2.10it/s]
#
# tqdm() Progress Bar Segments: 58it [00:38,  2.10it/s]
#
# tqdm() Progress Bar Segments: 59it [00:38,  2.11it/s]
#
# tqdm() Progress Bar Segments: 60it [00:39,  2.09it/s]
#
# tqdm() Progress Bar Segments: 61it [00:39,  2.10it/s]
#
# tqdm() Progress Bar Segments: 62it [00:40,  2.13it/s]
#
# tqdm() Progress Bar Segments: 63it [00:40,  2.17it/s]
#
# tqdm() Progress Bar Segments: 64it [00:40,  2.20it/s]
#
# tqdm() Progress Bar Segments: 65it [00:41,  2.21it/s]
#
# tqdm() Progress Bar Segments: 66it [00:41,  2.22it/s]
#
# tqdm() Progress Bar Segments: 67it [00:42,  2.22it/s]
#
# tqdm() Progress Bar Segments: 68it [00:42,  2.23it/s]
#
# tqdm() Progress Bar Segments: 69it [00:43,  2.23it/s]
#
# tqdm() Progress Bar Segments: 70it [00:43,  2.24it/s]
#
# tqdm() Progress Bar Segments: 71it [00:44,  2.25it/s]
#
# tqdm() Progress Bar Segments: 72it [00:44,  2.24it/s]
#
# tqdm() Progress Bar Segments: 73it [00:44,  2.24it/s]
#
# tqdm() Progress Bar Segments: 74it [00:45,  2.23it/s]
#
# tqdm() Progress Bar Segments: 75it [00:45,  2.24it/s]
#
# tqdm() Progress Bar Segments: 76it [00:46,  2.25it/s]
#
# tqdm() Progress Bar Segments: 77it [00:46,  2.09it/s]
#
# tqdm() Progress Bar Segments: 78it [00:47,  2.14it/s]
#
# tqdm() Progress Bar Segments: 79it [00:47,  2.19it/s]
#
# tqdm() Progress Bar Segments: 80it [00:48,  2.19it/s]
#
# tqdm() Progress Bar Segments: 81it [00:48,  2.21it/s]
#
# tqdm() Progress Bar Segments: 82it [00:49,  2.22it/s]
#
# tqdm() Progress Bar Segments: 83it [00:49,  2.21it/s]
#
# tqdm() Progress Bar Segments: 84it [00:50,  2.22it/s]
#
# tqdm() Progress Bar Segments: 85it [00:50,  2.22it/s]
#
# tqdm() Progress Bar Segments: 86it [00:50,  2.23it/s]
#
# tqdm() Progress Bar Segments: 87it [00:51,  2.24it/s]
#
# tqdm() Progress Bar Segments: 88it [00:51,  2.27it/s]
#
# tqdm() Progress Bar Segments: 89it [00:52,  2.26it/s]
#
# tqdm() Progress Bar Segments: 90it [00:52,  2.26it/s]
#
# tqdm() Progress Bar Segments: 91it [00:53,  2.28it/s]
#
# tqdm() Progress Bar Segments: 92it [00:53,  2.27it/s]
#
# tqdm() Progress Bar Segments: 93it [00:53,  2.25it/s]
#
# tqdm() Progress Bar Segments: 94it [00:54,  2.24it/s]
#
# tqdm() Progress Bar Segments: 95it [00:54,  2.24it/s]
#
# tqdm() Progress Bar Segments: 96it [00:55,  2.24it/s]
#
# tqdm() Progress Bar Segments: 97it [00:55,  2.24it/s]
#
# tqdm() Progress Bar Segments: 98it [00:56,  2.26it/s]
#
# tqdm() Progress Bar Segments: 99it [00:56,  2.22it/s]
#
# tqdm() Progress Bar Segments: 100it [00:57,  2.22it/s]
#
# tqdm() Progress Bar Segments: 101it [00:57,  2.22it/s]
#
# tqdm() Progress Bar Segments: 102it [00:58,  2.24it/s]
#
# tqdm() Progress Bar Segments: 103it [00:58,  2.20it/s]
#
# tqdm() Progress Bar Segments: 104it [00:58,  2.21it/s]
#
# tqdm() Progress Bar Segments: 105it [00:59,  2.22it/s]
#
# tqdm() Progress Bar Segments: 106it [00:59,  2.24it/s]
#
# tqdm() Progress Bar Segments: 107it [01:00,  2.23it/s]
#
# tqdm() Progress Bar Segments: 108it [01:00,  2.23it/s]
#
# tqdm() Progress Bar Segments: 109it [01:01,  2.23it/s]
#
# tqdm() Progress Bar Segments: 110it [01:01,  2.24it/s]
#
# tqdm() Progress Bar Segments: 111it [01:02,  2.25it/s]
#
# tqdm() Progress Bar Segments: 112it [01:02,  2.25it/s]
#
# tqdm() Progress Bar Segments: 113it [01:02,  2.26it/s]
#
# tqdm() Progress Bar Segments: 114it [01:03,  2.25it/s]
#
# tqdm() Progress Bar Segments: 115it [01:03,  2.23it/s]
#
# tqdm() Progress Bar Segments: 116it [01:04,  2.24it/s]
#
# tqdm() Progress Bar Segments: 117it [01:04,  2.25it/s]
#
# tqdm() Progress Bar Segments: 118it [01:05,  2.26it/s]
#
# tqdm() Progress Bar Segments: 119it [01:05,  2.27it/s]
#
# tqdm() Progress Bar Segments: 120it [01:06,  2.26it/s]
#
# tqdm() Progress Bar Segments: 121it [01:06,  2.27it/s]
#
# tqdm() Progress Bar Segments: 122it [01:06,  2.26it/s]
#
# tqdm() Progress Bar Segments: 123it [01:07,  2.27it/s]
#
# tqdm() Progress Bar Segments: 124it [01:07,  2.22it/s]
#
# tqdm() Progress Bar Segments: 125it [01:08,  2.25it/s]
#
# tqdm() Progress Bar Segments: 126it [01:08,  2.22it/s]
#
# tqdm() Progress Bar Segments: 127it [01:09,  2.23it/s]
#
# tqdm() Progress Bar Segments: 128it [01:09,  2.25it/s]
#
# tqdm() Progress Bar Segments: 129it [01:10,  2.22it/s]
#
# tqdm() Progress Bar Segments: 130it [01:10,  2.19it/s]
#
# tqdm() Progress Bar Segments: 131it [01:11,  2.15it/s]
#
# tqdm() Progress Bar Segments: 132it [01:11,  2.14it/s]
#
# tqdm() Progress Bar Segments: 133it [01:11,  2.12it/s]
#
# tqdm() Progress Bar Segments: 134it [01:12,  2.10it/s]
#
# tqdm() Progress Bar Segments: 135it [01:12,  2.08it/s]
#
# tqdm() Progress Bar Segments: 136it [01:13,  2.10it/s]
#
# tqdm() Progress Bar Segments: 137it [01:13,  2.09it/s]
#
# tqdm() Progress Bar Segments: 138it [01:14,  2.10it/s]
#
# tqdm() Progress Bar Segments: 139it [01:14,  2.09it/s]
#
# tqdm() Progress Bar Segments: 140it [01:15,  2.10it/s]
#
# tqdm() Progress Bar Segments: 141it [01:15,  2.10it/s]
#
# tqdm() Progress Bar Segments: 142it [01:16,  2.11it/s]
#
# tqdm() Progress Bar Segments: 143it [01:16,  2.11it/s]
#
# tqdm() Progress Bar Segments: 144it [01:17,  2.10it/s]
#
# tqdm() Progress Bar Segments: 145it [01:17,  2.11it/s]
#
# tqdm() Progress Bar Segments: 146it [01:18,  2.10it/s]
#
# tqdm() Progress Bar Segments: 147it [01:18,  2.10it/s]
#
# tqdm() Progress Bar Segments: 148it [01:19,  2.08it/s]
#
# tqdm() Progress Bar Segments: 149it [01:19,  2.09it/s]
#
# tqdm() Progress Bar Segments: 150it [01:20,  2.08it/s]
#
# tqdm() Progress Bar Segments: 151it [01:20,  2.10it/s]
#
# tqdm() Progress Bar Segments: 152it [01:21,  2.10it/s]
#
# tqdm() Progress Bar Segments: 153it [01:21,  2.09it/s]
#
# tqdm() Progress Bar Segments: 154it [01:22,  2.09it/s]
#
# tqdm() Progress Bar Segments: 155it [01:22,  2.10it/s]
#
# tqdm() Progress Bar Segments: 156it [01:22,  2.09it/s]
#
# tqdm() Progress Bar Segments: 157it [01:23,  2.09it/s]
#
# tqdm() Progress Bar Segments: 158it [01:23,  2.10it/s]
#
# tqdm() Progress Bar Segments: 159it [01:24,  2.08it/s]
#
# tqdm() Progress Bar Segments: 160it [01:24,  2.08it/s]
#
# tqdm() Progress Bar Segments: 161it [01:25,  2.09it/s]
#
# tqdm() Progress Bar Segments: 162it [01:25,  2.09it/s]
#
# tqdm() Progress Bar Segments: 163it [01:26,  2.06it/s]
#
# tqdm() Progress Bar Segments: 164it [01:26,  2.07it/s]
#
# tqdm() Progress Bar Segments: 165it [01:27,  2.07it/s]
#
# tqdm() Progress Bar Segments: 166it [01:27,  2.08it/s]
#
# tqdm() Progress Bar Segments: 167it [01:28,  2.08it/s]
#
# tqdm() Progress Bar Segments: 168it [01:28,  2.08it/s]
#
# tqdm() Progress Bar Segments: 169it [01:29,  2.09it/s]
#
# tqdm() Progress Bar Segments: 170it [01:29,  2.09it/s]
#
# tqdm() Progress Bar Segments: 171it [01:30,  2.09it/s]
#
# tqdm() Progress Bar Segments: 172it [01:30,  2.10it/s]
#
# tqdm() Progress Bar Segments: 173it [01:31,  2.09it/s]
#
# tqdm() Progress Bar Segments: 174it [01:31,  2.09it/s]
#
# tqdm() Progress Bar Segments: 175it [01:32,  2.10it/s]
#
# tqdm() Progress Bar Segments: 176it [01:32,  2.09it/s]
#
# tqdm() Progress Bar Segments: 177it [01:33,  2.11it/s]
#
# tqdm() Progress Bar Segments: 178it [01:33,  2.11it/s]
#
# tqdm() Progress Bar Segments: 179it [01:33,  2.12it/s]
#
# tqdm() Progress Bar Segments: 180it [01:34,  2.10it/s]
#
# tqdm() Progress Bar Segments: 181it [01:34,  2.12it/s]
#
# tqdm() Progress Bar Segments: 182it [01:35,  2.11it/s]
#
# tqdm() Progress Bar Segments: 183it [01:35,  2.10it/s]
#
# tqdm() Progress Bar Segments: 184it [01:36,  2.10it/s]
#
# tqdm() Progress Bar Segments: 185it [01:36,  2.11it/s]
#
# tqdm() Progress Bar Segments: 186it [01:37,  2.10it/s]
#
# tqdm() Progress Bar Segments: 187it [01:37,  2.10it/s]
#
# tqdm() Progress Bar Segments: 188it [01:38,  2.11it/s]
#
# tqdm() Progress Bar Segments: 189it [01:38,  2.11it/s]
#
# tqdm() Progress Bar Segments: 190it [01:39,  2.10it/s]
#
# tqdm() Progress Bar Segments: 191it [01:39,  2.10it/s]
#
# tqdm() Progress Bar Segments: 192it [01:40,  2.12it/s]
#
# tqdm() Progress Bar Segments: 193it [01:40,  2.14it/s]
#
# tqdm() Progress Bar Segments: 194it [01:41,  2.17it/s]
#
# tqdm() Progress Bar Segments: 195it [01:41,  2.17it/s]
#
# tqdm() Progress Bar Segments: 196it [01:41,  2.18it/s]
#
# tqdm() Progress Bar Segments: 197it [01:42,  2.18it/s]
#
# tqdm() Progress Bar Segments: 198it [01:42,  2.21it/s]
#
# tqdm() Progress Bar Segments: 199it [01:43,  2.22it/s]
#
# tqdm() Progress Bar Segments: 200it [01:43,  2.24it/s]
#
# tqdm() Progress Bar Segments: 201it [01:44,  2.08it/s]
#
# tqdm() Progress Bar Segments: 202it [01:44,  2.09it/s]
#
# tqdm() Progress Bar Segments: 203it [01:45,  1.97it/s]
#
# tqdm() Progress Bar Segments: 204it [01:45,  2.04it/s]
#
# tqdm() Progress Bar Segments: 205it [01:46,  2.11it/s]
#
# tqdm() Progress Bar Segments: 206it [01:46,  2.14it/s]
#
# tqdm() Progress Bar Segments: 207it [01:47,  2.18it/s]
#
# tqdm() Progress Bar Segments: 208it [01:47,  2.20it/s]
#
# tqdm() Progress Bar Segments: 209it [01:47,  2.22it/s]
#
# tqdm() Progress Bar Segments: 210it [01:48,  2.23it/s]
#
# tqdm() Progress Bar Segments: 211it [01:48,  2.26it/s]
#
# tqdm() Progress Bar Segments: 212it [01:49,  2.27it/s]
#
# tqdm() Progress Bar Segments: 213it [01:49,  2.24it/s]
#
# tqdm() Progress Bar Segments: 214it [01:50,  2.25it/s]
#
# tqdm() Progress Bar Segments: 215it [01:50,  2.25it/s]
#
# tqdm() Progress Bar Segments: 216it [01:51,  2.25it/s]
#
# tqdm() Progress Bar Segments: 217it [01:51,  2.26it/s]
#
# tqdm() Progress Bar Segments: 218it [01:51,  2.27it/s]
#
# tqdm() Progress Bar Segments: 219it [01:52,  2.27it/s]
#
# tqdm() Progress Bar Segments: 220it [01:52,  2.26it/s]
#
# tqdm() Progress Bar Segments: 221it [01:53,  2.26it/s]
#
# tqdm() Progress Bar Segments: 222it [01:53,  2.22it/s]
#
# tqdm() Progress Bar Segments: 223it [01:54,  2.24it/s]
#
# tqdm() Progress Bar Segments: 224it [01:54,  2.24it/s]
#
# tqdm() Progress Bar Segments: 225it [01:55,  2.26it/s]
#
# tqdm() Progress Bar Segments: 226it [01:55,  2.26it/s]
#
# tqdm() Progress Bar Segments: 227it [01:55,  2.26it/s]
#
# tqdm() Progress Bar Segments: 228it [01:56,  2.26it/s]
#
# tqdm() Progress Bar Segments: 229it [01:56,  2.25it/s]
#
# tqdm() Progress Bar Segments: 230it [01:57,  2.25it/s]
#
# tqdm() Progress Bar Segments: 231it [01:57,  2.22it/s]
#
# tqdm() Progress Bar Segments: 232it [01:58,  2.23it/s]
#
# tqdm() Progress Bar Segments: 233it [01:58,  2.24it/s]
#
# tqdm() Progress Bar Segments: 234it [01:59,  2.24it/s]
#
# tqdm() Progress Bar Segments: 235it [01:59,  2.25it/s]
#
# tqdm() Progress Bar Segments: 236it [01:59,  2.25it/s]
#
# tqdm() Progress Bar Segments: 237it [02:00,  2.21it/s]
#
# tqdm() Progress Bar Segments: 238it [02:00,  2.22it/s]
#
# tqdm() Progress Bar Segments: 239it [02:01,  2.22it/s]
#
# tqdm() Progress Bar Segments: 240it [02:01,  2.21it/s]
#
# tqdm() Progress Bar Segments: 241it [02:02,  2.22it/s]
#
# tqdm() Progress Bar Segments: 242it [02:02,  2.22it/s]
#
# tqdm() Progress Bar Segments: 243it [02:03,  2.22it/s]
#
# tqdm() Progress Bar Segments: 244it [02:03,  2.24it/s]
#
# tqdm() Progress Bar Segments: 245it [02:04,  2.24it/s]
#
# tqdm() Progress Bar Segments: 246it [02:04,  2.26it/s]
#
# tqdm() Progress Bar Segments: 247it [02:04,  2.26it/s]
#
# tqdm() Progress Bar Segments: 248it [02:05,  2.26it/s]
#
# tqdm() Progress Bar Segments: 249it [02:05,  2.26it/s]
#
# tqdm() Progress Bar Segments: 250it [02:06,  2.26it/s]
#
# tqdm() Progress Bar Segments: 251it [02:06,  2.27it/s]
#
# tqdm() Progress Bar Segments: 252it [02:07,  2.27it/s]
#
# tqdm() Progress Bar Segments: 253it [02:07,  2.25it/s]
#
# tqdm() Progress Bar Segments: 254it [02:08,  2.24it/s]
#
# tqdm() Progress Bar Segments: 255it [02:08,  2.25it/s]
#
# tqdm() Progress Bar Segments: 256it [02:08,  2.26it/s]
#
# tqdm() Progress Bar Segments: 257it [02:09,  2.26it/s]
#
# tqdm() Progress Bar Segments: 258it [02:09,  2.27it/s]
#
# tqdm() Progress Bar Segments: 259it [02:10,  2.22it/s]
#
# tqdm() Progress Bar Segments: 260it [02:10,  2.18it/s]
#
# tqdm() Progress Bar Segments: 261it [02:11,  2.13it/s]
#
# tqdm() Progress Bar Segments: 262it [02:11,  2.13it/s]
#
# tqdm() Progress Bar Segments: 263it [02:12,  2.11it/s]
#
# tqdm() Progress Bar Segments: 264it [02:12,  2.10it/s]
#
# tqdm() Progress Bar Segments: 265it [02:13,  2.10it/s]
#
# tqdm() Progress Bar Segments: 266it [02:13,  2.09it/s]
#
# tqdm() Progress Bar Segments: 267it [02:14,  2.09it/s]
#
# tqdm() Progress Bar Segments: 268it [02:14,  2.12it/s]
#
# tqdm() Progress Bar Segments: 269it [02:15,  2.09it/s]
#
# tqdm() Progress Bar Segments: 270it [02:15,  2.10it/s]
#
# tqdm() Progress Bar Segments: 271it [02:15,  2.11it/s]
#
# tqdm() Progress Bar Segments: 272it [02:16,  2.09it/s]
#
# tqdm() Progress Bar Segments: 273it [02:16,  2.10it/s]
#
# tqdm() Progress Bar Segments: 274it [02:17,  2.09it/s]
#
# tqdm() Progress Bar Segments: 275it [02:17,  2.10it/s]
#
# tqdm() Progress Bar Segments: 276it [02:18,  2.09it/s]
#
# tqdm() Progress Bar Segments: 277it [02:18,  2.10it/s]
#
# tqdm() Progress Bar Segments: 278it [02:19,  2.08it/s]
#
# tqdm() Progress Bar Segments: 279it [02:19,  2.10it/s]
#
# tqdm() Progress Bar Segments: 280it [02:20,  2.10it/s]
#
# tqdm() Progress Bar Segments: 281it [02:20,  2.10it/s]
#
# tqdm() Progress Bar Segments: 282it [02:21,  2.10it/s]
#
# tqdm() Progress Bar Segments: 283it [02:21,  2.10it/s]
#
# tqdm() Progress Bar Segments: 284it [02:22,  2.10it/s]
#
# tqdm() Progress Bar Segments: 285it [02:22,  2.10it/s]
#
# tqdm() Progress Bar Segments: 286it [02:23,  2.09it/s]
#
# tqdm() Progress Bar Segments: 287it [02:23,  2.10it/s]
#
# tqdm() Progress Bar Segments: 288it [02:24,  2.09it/s]
#
# tqdm() Progress Bar Segments: 289it [02:24,  2.09it/s]
#
# tqdm() Progress Bar Segments: 290it [02:25,  2.10it/s]
#
# tqdm() Progress Bar Segments: 291it [02:25,  2.10it/s]
#
# tqdm() Progress Bar Segments: 292it [02:26,  2.10it/s]
#
# tqdm() Progress Bar Segments: 293it [02:26,  2.08it/s]
#
# tqdm() Progress Bar Segments: 294it [02:26,  2.08it/s]
#
# tqdm() Progress Bar Segments: 295it [02:27,  2.04it/s]
#
# tqdm() Progress Bar Segments: 296it [02:27,  2.06it/s]
#
# tqdm() Progress Bar Segments: 297it [02:28,  2.06it/s]
#
# tqdm() Progress Bar Segments: 298it [02:28,  2.08it/s]
#
# tqdm() Progress Bar Segments: 299it [02:29,  2.08it/s]
#
# tqdm() Progress Bar Segments: 300it [02:29,  2.10it/s]
#
# tqdm() Progress Bar Segments: 301it [02:30,  2.09it/s]
#
# tqdm() Progress Bar Segments: 302it [02:30,  2.10it/s]
#
# tqdm() Progress Bar Segments: 303it [02:31,  2.11it/s]
#
# tqdm() Progress Bar Segments: 304it [02:31,  2.11it/s]
#
# tqdm() Progress Bar Segments: 305it [02:32,  2.12it/s]
#
# tqdm() Progress Bar Segments: 306it [02:32,  2.12it/s]
#
# tqdm() Progress Bar Segments: 307it [02:33,  2.12it/s]
#
# tqdm() Progress Bar Segments: 308it [02:33,  2.11it/s]
#
# tqdm() Progress Bar Segments: 309it [02:34,  2.11it/s]
#
# tqdm() Progress Bar Segments: 310it [02:34,  2.11it/s]
#
# tqdm() Progress Bar Segments: 311it [02:35,  2.13it/s]
#
# tqdm() Progress Bar Segments: 312it [02:35,  2.11it/s]
#
# tqdm() Progress Bar Segments: 313it [02:36,  2.13it/s]
#
# tqdm() Progress Bar Segments: 314it [02:36,  2.13it/s]
#
# tqdm() Progress Bar Segments: 315it [02:36,  2.12it/s]
#
# tqdm() Progress Bar Segments: 316it [02:37,  2.13it/s]
#
# tqdm() Progress Bar Segments: 317it [02:37,  2.12it/s]
#
# tqdm() Progress Bar Segments: 318it [02:38,  2.13it/s]
#
# tqdm() Progress Bar Segments: 319it [02:38,  2.13it/s]
#
# tqdm() Progress Bar Segments: 320it [02:39,  2.11it/s]
#
# tqdm() Progress Bar Segments: 321it [02:39,  2.12it/s]
#
# tqdm() Progress Bar Segments: 322it [02:40,  2.14it/s]
#
# tqdm() Progress Bar Segments: 323it [02:40,  2.16it/s]
#
# tqdm() Progress Bar Segments: 324it [02:41,  2.20it/s]
#
# tqdm() Progress Bar Segments: 325it [02:41,  2.22it/s]
#
# tqdm() Progress Bar Segments: 326it [02:42,  2.24it/s]
#
# tqdm() Progress Bar Segments: 327it [02:42,  2.26it/s]
#
# tqdm() Progress Bar Segments: 328it [02:42,  2.27it/s]
#
# tqdm() Progress Bar Segments: 329it [02:43,  2.27it/s]
#
# tqdm() Progress Bar Segments: 330it [02:43,  2.27it/s]
#
# tqdm() Progress Bar Segments: 331it [02:44,  2.27it/s]
#
# tqdm() Progress Bar Segments: 332it [02:44,  2.26it/s]
#
# tqdm() Progress Bar Segments: 333it [02:45,  2.26it/s]
#
# tqdm() Progress Bar Segments: 334it [02:45,  2.28it/s]
#
# tqdm() Progress Bar Segments: 335it [02:45,  2.28it/s]
#
# tqdm() Progress Bar Segments: 336it [02:46,  2.29it/s]
#
# tqdm() Progress Bar Segments: 337it [02:46,  2.27it/s]
#
# tqdm() Progress Bar Segments: 338it [02:47,  2.27it/s]
#
# tqdm() Progress Bar Segments: 339it [02:47,  2.28it/s]
#
# tqdm() Progress Bar Segments: 340it [02:48,  2.29it/s]
#
# tqdm() Progress Bar Segments: 341it [02:48,  2.29it/s]
#
# tqdm() Progress Bar Segments: 342it [02:49,  2.28it/s]
#
# tqdm() Progress Bar Segments: 343it [02:49,  2.28it/s]
#
# tqdm() Progress Bar Segments: 344it [02:49,  2.27it/s]
#
# tqdm() Progress Bar Segments: 345it [02:50,  2.28it/s]
#
# tqdm() Progress Bar Segments: 346it [02:50,  2.28it/s]
#
# tqdm() Progress Bar Segments: 347it [02:51,  2.28it/s]
#
# tqdm() Progress Bar Segments: 348it [02:51,  2.30it/s]
#
# tqdm() Progress Bar Segments: 349it [02:52,  2.28it/s]
#
# tqdm() Progress Bar Segments: 350it [02:52,  2.28it/s]
#
# tqdm() Progress Bar Segments: 351it [02:52,  2.27it/s]
#
# tqdm() Progress Bar Segments: 352it [02:53,  2.27it/s]
#
# tqdm() Progress Bar Segments: 353it [02:53,  2.25it/s]
#
# tqdm() Progress Bar Segments: 354it [02:54,  2.26it/s]
#
# tqdm() Progress Bar Segments: 355it [02:54,  2.27it/s]
#
# tqdm() Progress Bar Segments: 356it [02:55,  2.26it/s]
#
# tqdm() Progress Bar Segments: 357it [02:55,  2.27it/s]
#
# tqdm() Progress Bar Segments: 358it [02:56,  2.28it/s]
#
# tqdm() Progress Bar Segments: 359it [02:56,  2.28it/s]
#
# tqdm() Progress Bar Segments: 360it [02:56,  2.28it/s]
#
# tqdm() Progress Bar Segments: 361it [02:57,  2.28it/s]
#
# tqdm() Progress Bar Segments: 362it [02:57,  2.29it/s]
#
# tqdm() Progress Bar Segments: 363it [02:58,  2.29it/s]
#
# tqdm() Progress Bar Segments: 364it [02:58,  2.29it/s]
#
# tqdm() Progress Bar Segments: 365it [02:59,  2.28it/s]
#
# tqdm() Progress Bar Segments: 366it [02:59,  2.30it/s]
#
# tqdm() Progress Bar Segments: 367it [02:59,  2.28it/s]
#
# tqdm() Progress Bar Segments: 368it [03:00,  2.29it/s]
#
# tqdm() Progress Bar Segments: 369it [03:00,  2.29it/s]
#
# tqdm() Progress Bar Segments: 370it [03:01,  2.28it/s]
#
# tqdm() Progress Bar Segments: 371it [03:01,  2.26it/s]
#
# tqdm() Progress Bar Segments: 372it [03:02,  2.29it/s]
#
# tqdm() Progress Bar Segments: 373it [03:02,  2.31it/s]
#
# tqdm() Progress Bar Segments: 374it [03:03,  2.30it/s]
#
# tqdm() Progress Bar Segments: 375it [03:03,  2.31it/s]
#
# tqdm() Progress Bar Segments: 376it [03:03,  2.27it/s]
#
# tqdm() Progress Bar Segments: 377it [03:04,  2.26it/s]
#
# tqdm() Progress Bar Segments: 378it [03:04,  2.27it/s]
#
# tqdm() Progress Bar Segments: 379it [03:05,  2.27it/s]
#
# tqdm() Progress Bar Segments: 380it [03:05,  2.28it/s]
#
# tqdm() Progress Bar Segments: 381it [03:06,  2.27it/s]
#
# tqdm() Progress Bar Segments: 382it [03:06,  2.28it/s]
#
# tqdm() Progress Bar Segments: 383it [03:07,  2.28it/s]
#
# tqdm() Progress Bar Segments: 384it [03:07,  2.27it/s]
#
# tqdm() Progress Bar Segments: 385it [03:07,  2.27it/s]
#
# tqdm() Progress Bar Segments: 386it [03:08,  2.26it/s]
#
# tqdm() Progress Bar Segments: 387it [03:08,  2.26it/s]
#
# tqdm() Progress Bar Segments: 388it [03:09,  2.23it/s]
#
# tqdm() Progress Bar Segments: 389it [03:09,  2.27it/s]
#
# tqdm() Progress Bar Segments: 390it [03:10,  2.24it/s]
#
# tqdm() Progress Bar Segments: 391it [03:10,  2.20it/s]
#
# tqdm() Progress Bar Segments: 392it [03:11,  2.18it/s]
#
# tqdm() Progress Bar Segments: 393it [03:11,  2.15it/s]
#
# tqdm() Progress Bar Segments: 394it [03:12,  2.14it/s]
#
# tqdm() Progress Bar Segments: 395it [03:12,  2.12it/s]
#
# tqdm() Progress Bar Segments: 396it [03:12,  2.12it/s]
#
# tqdm() Progress Bar Segments: 397it [03:13,  2.12it/s]
#
# tqdm() Progress Bar Segments: 398it [03:13,  2.12it/s]
#
# tqdm() Progress Bar Segments: 399it [03:14,  2.11it/s]
#
# tqdm() Progress Bar Segments: 400it [03:14,  2.13it/s]
#
# tqdm() Progress Bar Segments: 401it [03:15,  2.10it/s]
#
# tqdm() Progress Bar Segments: 402it [03:15,  2.11it/s]
#
# tqdm() Progress Bar Segments: 403it [03:16,  2.10it/s]
#
# tqdm() Progress Bar Segments: 404it [03:16,  2.11it/s]
#
# tqdm() Progress Bar Segments: 405it [03:17,  2.12it/s]
#
# tqdm() Progress Bar Segments: 406it [03:17,  2.12it/s]
#
# tqdm() Progress Bar Segments: 407it [03:18,  2.13it/s]
#
# tqdm() Progress Bar Segments: 408it [03:18,  2.13it/s]
#
# tqdm() Progress Bar Segments: 409it [03:19,  2.12it/s]
#
# tqdm() Progress Bar Segments: 410it [03:19,  2.12it/s]
#
# tqdm() Progress Bar Segments: 411it [03:20,  2.12it/s]
#
# tqdm() Progress Bar Segments: 412it [03:20,  2.12it/s]
#
# tqdm() Progress Bar Segments: 413it [03:20,  2.13it/s]
#
# tqdm() Progress Bar Segments: 414it [03:21,  2.13it/s]
#
# tqdm() Progress Bar Segments: 415it [03:21,  2.13it/s]
#
# tqdm() Progress Bar Segments: 416it [03:22,  2.13it/s]
#
# tqdm() Progress Bar Segments: 417it [03:22,  2.14it/s]
#
# tqdm() Progress Bar Segments: 418it [03:23,  2.13it/s]
#
# tqdm() Progress Bar Segments: 419it [03:23,  2.14it/s]
#
# tqdm() Progress Bar Segments: 420it [03:24,  2.14it/s]
#
# tqdm() Progress Bar Segments: 421it [03:24,  2.12it/s]
#
# tqdm() Progress Bar Segments: 422it [03:25,  2.12it/s]
#
# tqdm() Progress Bar Segments: 423it [03:25,  2.13it/s]
#
# tqdm() Progress Bar Segments: 424it [03:26,  2.13it/s]
#
# tqdm() Progress Bar Segments: 425it [03:26,  2.12it/s]
#
# tqdm() Progress Bar Segments: 426it [03:27,  2.11it/s]
#
# tqdm() Progress Bar Segments: 427it [03:27,  2.11it/s]
#
# tqdm() Progress Bar Segments: 428it [03:28,  2.11it/s]
#
# tqdm() Progress Bar Segments: 429it [03:28,  2.11it/s]
#
# tqdm() Progress Bar Segments: 430it [03:28,  2.12it/s]
#
# tqdm() Progress Bar Segments: 431it [03:29,  2.11it/s]
#
# tqdm() Progress Bar Segments: 432it [03:29,  2.11it/s]
#
# tqdm() Progress Bar Segments: 433it [03:30,  2.11it/s]
#
# tqdm() Progress Bar Segments: 434it [03:30,  2.12it/s]
#
# tqdm() Progress Bar Segments: 435it [03:31,  2.13it/s]
#
# tqdm() Progress Bar Segments: 436it [03:31,  2.11it/s]
#
# tqdm() Progress Bar Segments: 437it [03:32,  2.12it/s]
#
# tqdm() Progress Bar Segments: 438it [03:32,  2.12it/s]
#
# tqdm() Progress Bar Segments: 439it [03:33,  2.13it/s]
#
# tqdm() Progress Bar Segments: 440it [03:33,  2.13it/s]
#
# tqdm() Progress Bar Segments: 441it [03:34,  2.13it/s]
#
# tqdm() Progress Bar Segments: 442it [03:34,  2.13it/s]
#
# tqdm() Progress Bar Segments: 443it [03:35,  2.13it/s]
#
# tqdm() Progress Bar Segments: 444it [03:35,  2.14it/s]
#
# tqdm() Progress Bar Segments: 445it [03:36,  2.12it/s]
#
# tqdm() Progress Bar Segments: 446it [03:36,  2.13it/s]
#
# tqdm() Progress Bar Segments: 447it [03:37,  2.11it/s]
#
# tqdm() Progress Bar Segments: 448it [03:37,  2.11it/s]
#
# tqdm() Progress Bar Segments: 449it [03:37,  2.11it/s]
#
# tqdm() Progress Bar Segments: 450it [03:38,  2.12it/s]
#
# tqdm() Progress Bar Segments: 451it [03:38,  2.09it/s]
#
# tqdm() Progress Bar Segments: 452it [03:39,  2.10it/s]
#
# tqdm() Progress Bar Segments: 453it [03:39,  2.12it/s]
#
# tqdm() Progress Bar Segments: 454it [03:40,  2.18it/s]
#
# tqdm() Progress Bar Segments: 455it [03:40,  2.21it/s]
#
# tqdm() Progress Bar Segments: 456it [03:41,  2.21it/s]
#
# tqdm() Progress Bar Segments: 457it [03:41,  2.23it/s]
#
# tqdm() Progress Bar Segments: 458it [03:42,  2.23it/s]
#
# tqdm() Progress Bar Segments: 459it [03:42,  2.24it/s]
#
# tqdm() Progress Bar Segments: 460it [03:42,  2.25it/s]
#
# tqdm() Progress Bar Segments: 461it [03:43,  2.26it/s]
#
# tqdm() Progress Bar Segments: 462it [03:43,  2.26it/s]
#
# tqdm() Progress Bar Segments: 463it [03:44,  2.28it/s]
#
# tqdm() Progress Bar Segments: 464it [03:44,  2.29it/s]
#
# tqdm() Progress Bar Segments: 465it [03:45,  2.25it/s]
#
# tqdm() Progress Bar Segments: 466it [03:45,  2.27it/s]
#
# tqdm() Progress Bar Segments: 467it [03:46,  2.27it/s]
#
# tqdm() Progress Bar Segments: 468it [03:46,  2.29it/s]
#
# tqdm() Progress Bar Segments: 469it [03:46,  2.29it/s]
#
# tqdm() Progress Bar Segments: 470it [03:47,  2.30it/s]
#
# tqdm() Progress Bar Segments: 471it [03:47,  2.31it/s]
#
# tqdm() Progress Bar Segments: 472it [03:48,  2.31it/s]
#
# tqdm() Progress Bar Segments: 473it [03:48,  2.31it/s]
#
# tqdm() Progress Bar Segments: 474it [03:49,  2.31it/s]
#
# tqdm() Progress Bar Segments: 475it [03:49,  2.29it/s]
#
# tqdm() Progress Bar Segments: 476it [03:49,  2.28it/s]
#
# tqdm() Progress Bar Segments: 477it [03:50,  2.29it/s]
#
# tqdm() Progress Bar Segments: 478it [03:50,  2.30it/s]
#
# tqdm() Progress Bar Segments: 479it [03:51,  2.29it/s]
#
# tqdm() Progress Bar Segments: 480it [03:51,  2.29it/s]
#
# tqdm() Progress Bar Segments: 481it [03:52,  2.27it/s]
#
# tqdm() Progress Bar Segments: 482it [03:52,  2.27it/s]
#
# tqdm() Progress Bar Segments: 483it [03:52,  2.27it/s]
#
# tqdm() Progress Bar Segments: 484it [03:53,  2.28it/s]
#
# tqdm() Progress Bar Segments: 485it [03:53,  2.29it/s]
#
# tqdm() Progress Bar Segments: 486it [03:54,  2.28it/s]
#
# tqdm() Progress Bar Segments: 487it [03:54,  2.27it/s]
#
# tqdm() Progress Bar Segments: 488it [03:55,  2.26it/s]
#
# tqdm() Progress Bar Segments: 489it [03:55,  2.28it/s]
#
# tqdm() Progress Bar Segments: 490it [03:56,  2.28it/s]
#
# tqdm() Progress Bar Segments: 491it [03:56,  2.29it/s]
#
# tqdm() Progress Bar Segments: 492it [03:56,  2.29it/s]
#
# tqdm() Progress Bar Segments: 493it [03:57,  2.29it/s]
#
# tqdm() Progress Bar Segments: 494it [03:57,  2.29it/s]
#
# tqdm() Progress Bar Segments: 495it [03:58,  2.27it/s]
#
# tqdm() Progress Bar Segments: 496it [03:58,  2.29it/s]
#
# tqdm() Progress Bar Segments: 497it [03:59,  2.28it/s]
#
# tqdm() Progress Bar Segments: 498it [03:59,  2.29it/s]
#
# tqdm() Progress Bar Segments: 499it [03:59,  2.30it/s]
#
# tqdm() Progress Bar Segments: 500it [04:00,  2.27it/s]
#
# tqdm() Progress Bar Segments: 501it [04:00,  2.28it/s]
#
# tqdm() Progress Bar Segments: 502it [04:01,  2.27it/s]
#
# tqdm() Progress Bar Segments: 503it [04:01,  2.29it/s]
#
# tqdm() Progress Bar Segments: 504it [04:02,  2.26it/s]
#
# tqdm() Progress Bar Segments: 505it [04:02,  2.28it/s]
#
# tqdm() Progress Bar Segments: 506it [04:03,  2.28it/s]
#
# tqdm() Progress Bar Segments: 507it [04:03,  2.28it/s]
#
# tqdm() Progress Bar Segments: 508it [04:03,  2.28it/s]
#
# tqdm() Progress Bar Segments: 509it [04:04,  2.27it/s]
#
# tqdm() Progress Bar Segments: 510it [04:04,  2.28it/s]
#
# tqdm() Progress Bar Segments: 511it [04:05,  2.28it/s]
#
# tqdm() Progress Bar Segments: 512it [04:05,  2.29it/s]
#
# tqdm() Progress Bar Segments: 513it [04:06,  2.28it/s]
#
# tqdm() Progress Bar Segments: 514it [04:06,  2.26it/s]
#
# tqdm() Progress Bar Segments: 515it [04:07,  2.26it/s]
#
# tqdm() Progress Bar Segments: 516it [04:07,  2.25it/s]
#
# tqdm() Progress Bar Segments: 517it [04:07,  2.29it/s]
#
# tqdm() Progress Bar Segments: 518it [04:08,  2.28it/s]
#
# tqdm() Progress Bar Segments: 519it [04:08,  2.28it/s]
#
# tqdm() Progress Bar Segments: 520it [04:09,  2.28it/s]
#
# tqdm() Progress Bar Segments: 521it [04:09,  2.28it/s]
#
# tqdm() Progress Bar Segments: 522it [04:10,  2.23it/s]
#
# tqdm() Progress Bar Segments: 523it [04:10,  2.18it/s]
#
# tqdm() Progress Bar Segments: 524it [04:11,  2.18it/s]
#
# tqdm() Progress Bar Segments: 525it [04:11,  2.16it/s]
#
# tqdm() Progress Bar Segments: 526it [04:12,  2.15it/s]
#
# tqdm() Progress Bar Segments: 527it [04:12,  2.13it/s]
#
# tqdm() Progress Bar Segments: 528it [04:12,  2.14it/s]
#
# tqdm() Progress Bar Segments: 529it [04:13,  2.14it/s]
#
# tqdm() Progress Bar Segments: 530it [04:13,  2.13it/s]
#
# tqdm() Progress Bar Segments: 531it [04:14,  2.12it/s]
#
# tqdm() Progress Bar Segments: 532it [04:14,  2.13it/s]
#
# tqdm() Progress Bar Segments: 533it [04:15,  2.12it/s]
#
# tqdm() Progress Bar Segments: 534it [04:15,  2.13it/s]
#
# tqdm() Progress Bar Segments: 535it [04:16,  2.13it/s]
#
# tqdm() Progress Bar Segments: 536it [04:16,  2.13it/s]
#
# tqdm() Progress Bar Segments: 537it [04:17,  2.14it/s]
#
# tqdm() Progress Bar Segments: 538it [04:17,  2.13it/s]
#
# tqdm() Progress Bar Segments: 539it [04:18,  2.15it/s]
#
# tqdm() Progress Bar Segments: 540it [04:18,  2.13it/s]
#
# tqdm() Progress Bar Segments: 541it [04:19,  2.13it/s]
#
# tqdm() Progress Bar Segments: 542it [04:19,  2.13it/s]
#
# tqdm() Progress Bar Segments: 543it [04:20,  2.13it/s]
#
# tqdm() Progress Bar Segments: 544it [04:20,  2.13it/s]
#
# tqdm() Progress Bar Segments: 545it [04:20,  2.14it/s]
#
# tqdm() Progress Bar Segments: 546it [04:21,  2.14it/s]
#
# tqdm() Progress Bar Segments: 547it [04:21,  2.12it/s]
#
# tqdm() Progress Bar Segments: 548it [04:22,  2.13it/s]
#
# tqdm() Progress Bar Segments: 549it [04:22,  2.12it/s]
#
# tqdm() Progress Bar Segments: 550it [04:23,  2.11it/s]
#
# tqdm() Progress Bar Segments: 551it [04:23,  2.11it/s]
#
# tqdm() Progress Bar Segments: 552it [04:24,  2.11it/s]
#
# tqdm() Progress Bar Segments: 553it [04:24,  2.12it/s]
#
# tqdm() Progress Bar Segments: 554it [04:25,  2.13it/s]
#
# tqdm() Progress Bar Segments: 555it [04:25,  2.13it/s]
#
# tqdm() Progress Bar Segments: 556it [04:26,  2.13it/s]
#
# tqdm() Progress Bar Segments: 557it [04:26,  2.14it/s]
#
# tqdm() Progress Bar Segments: 558it [04:27,  2.13it/s]
#
# tqdm() Progress Bar Segments: 559it [04:27,  2.13it/s]
#
# tqdm() Progress Bar Segments: 560it [04:28,  2.10it/s]
#
# tqdm() Progress Bar Segments: 561it [04:28,  2.11it/s]
#
# tqdm() Progress Bar Segments: 562it [04:28,  2.11it/s]
#
# tqdm() Progress Bar Segments: 563it [04:29,  2.10it/s]
#
# tqdm() Progress Bar Segments: 564it [04:29,  2.11it/s]
#
# tqdm() Progress Bar Segments: 565it [04:30,  2.11it/s]
#
# tqdm() Progress Bar Segments: 566it [04:30,  2.10it/s]
#
# tqdm() Progress Bar Segments: 567it [04:31,  2.11it/s]
#
# tqdm() Progress Bar Segments: 568it [04:31,  2.12it/s]
#
# tqdm() Progress Bar Segments: 569it [04:32,  2.13it/s]
#
# tqdm() Progress Bar Segments: 570it [04:32,  2.12it/s]
#
# tqdm() Progress Bar Segments: 571it [04:33,  2.13it/s]
#
# tqdm() Progress Bar Segments: 572it [04:33,  2.13it/s]
#
# tqdm() Progress Bar Segments: 573it [04:34,  2.13it/s]
#
# tqdm() Progress Bar Segments: 574it [04:34,  2.13it/s]
#
# tqdm() Progress Bar Segments: 575it [04:35,  2.13it/s]
#
# tqdm() Progress Bar Segments: 576it [04:35,  2.14it/s]
#
# tqdm() Progress Bar Segments: 577it [04:36,  2.13it/s]
#
# tqdm() Progress Bar Segments: 578it [04:36,  2.13it/s]
#
# tqdm() Progress Bar Segments: 579it [04:36,  2.12it/s]
#
# tqdm() Progress Bar Segments: 580it [04:37,  2.12it/s]
#
# tqdm() Progress Bar Segments: 581it [04:37,  2.11it/s]
#
# tqdm() Progress Bar Segments: 582it [04:38,  2.11it/s]
#
# tqdm() Progress Bar Segments: 583it [04:38,  2.10it/s]
#
# tqdm() Progress Bar Segments: 584it [04:39,  2.12it/s]
#
# tqdm() Progress Bar Segments: 585it [04:39,  2.12it/s]
#
# tqdm() Progress Bar Segments: 586it [04:40,  2.17it/s]
#
# tqdm() Progress Bar Segments: 587it [04:40,  2.22it/s]
#
# tqdm() Progress Bar Segments: 588it [04:41,  2.23it/s]
#
# tqdm() Progress Bar Segments: 589it [04:41,  2.25it/s]
#
# tqdm() Progress Bar Segments: 590it [04:41,  2.24it/s]
#
# tqdm() Progress Bar Segments: 591it [04:42,  2.26it/s]
#
# tqdm() Progress Bar Segments: 592it [04:42,  2.27it/s]
#
# tqdm() Progress Bar Segments: 593it [04:43,  2.27it/s]
#
# tqdm() Progress Bar Segments: 594it [04:43,  2.30it/s]
#
# tqdm() Progress Bar Segments: 595it [04:44,  2.29it/s]
#
# tqdm() Progress Bar Segments: 596it [04:44,  2.31it/s]
#
# tqdm() Progress Bar Segments: 597it [04:45,  2.31it/s]
#
# tqdm() Progress Bar Segments: 598it [04:45,  2.29it/s]
#
# tqdm() Progress Bar Segments: 599it [04:45,  2.29it/s]
#
# tqdm() Progress Bar Segments: 600it [04:46,  2.29it/s]
#
# tqdm() Progress Bar Segments: 601it [04:46,  2.29it/s]
#
# tqdm() Progress Bar Segments: 602it [04:47,  2.27it/s]
#
# tqdm() Progress Bar Segments: 603it [04:47,  2.28it/s]
#
# tqdm() Progress Bar Segments: 604it [04:48,  2.28it/s]
#
# tqdm() Progress Bar Segments: 605it [04:48,  2.30it/s]
#
# tqdm() Progress Bar Segments: 606it [04:48,  2.29it/s]
#
# tqdm() Progress Bar Segments: 607it [04:49,  2.28it/s]
#
# tqdm() Progress Bar Segments: 608it [04:49,  2.28it/s]
#
# tqdm() Progress Bar Segments: 609it [04:50,  2.28it/s]
#
# tqdm() Progress Bar Segments: 610it [04:50,  2.29it/s]
#
# tqdm() Progress Bar Segments: 611it [04:51,  2.29it/s]
#
# tqdm() Progress Bar Segments: 612it [04:51,  2.30it/s]
#
# tqdm() Progress Bar Segments: 613it [04:52,  2.31it/s]
#
# tqdm() Progress Bar Segments: 614it [04:52,  2.29it/s]
#
# tqdm() Progress Bar Segments: 615it [04:52,  2.31it/s]
#
# tqdm() Progress Bar Segments: 616it [04:53,  2.28it/s]
#
# tqdm() Progress Bar Segments: 617it [04:53,  2.29it/s]
#
# tqdm() Progress Bar Segments: 618it [04:54,  2.27it/s]
#
# tqdm() Progress Bar Segments: 619it [04:54,  2.28it/s]
#
# tqdm() Progress Bar Segments: 620it [04:55,  2.29it/s]
#
# tqdm() Progress Bar Segments: 621it [04:55,  2.28it/s]
#
# tqdm() Progress Bar Segments: 622it [04:55,  2.28it/s]
#
# tqdm() Progress Bar Segments: 623it [04:56,  2.27it/s]
#
# tqdm() Progress Bar Segments: 624it [04:56,  2.29it/s]
#
# tqdm() Progress Bar Segments: 625it [04:57,  2.27it/s]
#
# tqdm() Progress Bar Segments: 626it [04:57,  2.28it/s]
#
# tqdm() Progress Bar Segments: 627it [04:58,  2.29it/s]
#
# tqdm() Progress Bar Segments: 628it [04:58,  2.28it/s]
#
# tqdm() Progress Bar Segments: 629it [04:59,  2.29it/s]
#
# tqdm() Progress Bar Segments: 630it [04:59,  2.27it/s]
#
# tqdm() Progress Bar Segments: 631it [04:59,  2.28it/s]
#
# tqdm() Progress Bar Segments: 632it [05:00,  2.27it/s]
#
# tqdm() Progress Bar Segments: 633it [05:00,  2.29it/s]
#
# tqdm() Progress Bar Segments: 634it [05:01,  2.28it/s]
#
# tqdm() Progress Bar Segments: 635it [05:01,  2.28it/s]
#
# tqdm() Progress Bar Segments: 636it [05:02,  2.27it/s]
#
# tqdm() Progress Bar Segments: 637it [05:02,  2.27it/s]
#
# tqdm() Progress Bar Segments: 638it [05:02,  2.29it/s]
#
# tqdm() Progress Bar Segments: 639it [05:03,  2.29it/s]
#
# tqdm() Progress Bar Segments: 640it [05:03,  2.29it/s]
#
# tqdm() Progress Bar Segments: 641it [05:04,  2.31it/s]
#
# tqdm() Progress Bar Segments: 642it [05:04,  2.31it/s]
#
# tqdm() Progress Bar Segments: 643it [05:05,  2.30it/s]
#
# tqdm() Progress Bar Segments: 644it [05:05,  2.30it/s]
#
# tqdm() Progress Bar Segments: 645it [05:06,  2.32it/s]
#
# tqdm() Progress Bar Segments: 646it [05:06,  2.31it/s]
#
# tqdm() Progress Bar Segments: 647it [05:06,  2.31it/s]
#
# tqdm() Progress Bar Segments: 648it [05:07,  2.32it/s]
#
# tqdm() Progress Bar Segments: 649it [05:07,  2.28it/s]
#
# tqdm() Progress Bar Segments: 650it [05:08,  2.29it/s]
#
# tqdm() Progress Bar Segments: 651it [05:08,  2.27it/s]
#
# tqdm() Progress Bar Segments: 652it [05:09,  2.27it/s]
#
# tqdm() Progress Bar Segments: 653it [05:09,  2.25it/s]
#
# tqdm() Progress Bar Segments: 654it [05:10,  2.22it/s]
#
# tqdm() Progress Bar Segments: 655it [05:10,  2.17it/s]
#
# tqdm() Progress Bar Segments: 656it [05:10,  2.17it/s]
#
# tqdm() Progress Bar Segments: 657it [05:11,  2.16it/s]
#
# tqdm() Progress Bar Segments: 658it [05:11,  2.15it/s]
#
# tqdm() Progress Bar Segments: 659it [05:12,  2.14it/s]
#
# tqdm() Progress Bar Segments: 660it [05:12,  2.14it/s]
#
# tqdm() Progress Bar Segments: 661it [05:13,  2.14it/s]
#
# tqdm() Progress Bar Segments: 662it [05:13,  2.12it/s]
#
# tqdm() Progress Bar Segments: 663it [05:14,  2.13it/s]
#
# tqdm() Progress Bar Segments: 664it [05:14,  2.11it/s]
#
# tqdm() Progress Bar Segments: 665it [05:15,  2.11it/s]
#
# tqdm() Progress Bar Segments: 666it [05:15,  2.11it/s]
#
# tqdm() Progress Bar Segments: 667it [05:16,  2.12it/s]
#
# tqdm() Progress Bar Segments: 668it [05:16,  2.10it/s]
#
# tqdm() Progress Bar Segments: 669it [05:17,  2.11it/s]
#
# tqdm() Progress Bar Segments: 670it [05:17,  2.10it/s]
#
# tqdm() Progress Bar Segments: 671it [05:18,  2.10it/s]
#
# tqdm() Progress Bar Segments: 672it [05:18,  2.11it/s]
#
# tqdm() Progress Bar Segments: 673it [05:18,  2.11it/s]
#
# tqdm() Progress Bar Segments: 674it [05:19,  2.11it/s]
#
# tqdm() Progress Bar Segments: 675it [05:19,  2.11it/s]
#
# tqdm() Progress Bar Segments: 676it [05:20,  2.11it/s]
#
# tqdm() Progress Bar Segments: 677it [05:20,  2.11it/s]
#
# tqdm() Progress Bar Segments: 678it [05:21,  2.12it/s]
#
# tqdm() Progress Bar Segments: 679it [05:21,  2.10it/s]
#
# tqdm() Progress Bar Segments: 680it [05:22,  2.12it/s]
#
# tqdm() Progress Bar Segments: 681it [05:22,  2.12it/s]
#
# tqdm() Progress Bar Segments: 682it [05:23,  2.12it/s]
#
# tqdm() Progress Bar Segments: 683it [05:23,  2.13it/s]
#
# tqdm() Progress Bar Segments: 684it [05:24,  2.13it/s]
#
# tqdm() Progress Bar Segments: 685it [05:24,  2.12it/s]
#
# tqdm() Progress Bar Segments: 686it [05:25,  2.12it/s]
#
# tqdm() Progress Bar Segments: 687it [05:25,  2.12it/s]
#
# tqdm() Progress Bar Segments: 688it [05:26,  2.10it/s]
#
# tqdm() Progress Bar Segments: 689it [05:26,  2.10it/s]
#
# tqdm() Progress Bar Segments: 690it [05:27,  2.11it/s]
#
# tqdm() Progress Bar Segments: 691it [05:27,  2.13it/s]
#
# tqdm() Progress Bar Segments: 692it [05:27,  2.12it/s]
#
# tqdm() Progress Bar Segments: 693it [05:28,  2.12it/s]
#
# tqdm() Progress Bar Segments: 694it [05:28,  2.09it/s]
#
# tqdm() Progress Bar Segments: 695it [05:29,  2.10it/s]
#
# tqdm() Progress Bar Segments: 696it [05:29,  2.10it/s]
#
# tqdm() Progress Bar Segments: 697it [05:30,  2.10it/s]
#
# tqdm() Progress Bar Segments: 698it [05:30,  2.11it/s]
#
# tqdm() Progress Bar Segments: 699it [05:31,  2.10it/s]
#
# tqdm() Progress Bar Segments: 700it [05:31,  2.10it/s]
#
# tqdm() Progress Bar Segments: 701it [05:32,  2.10it/s]
#
# tqdm() Progress Bar Segments: 702it [05:32,  2.11it/s]
#
# tqdm() Progress Bar Segments: 703it [05:33,  2.10it/s]
#
# tqdm() Progress Bar Segments: 704it [05:33,  2.12it/s]
#
# tqdm() Progress Bar Segments: 705it [05:34,  2.12it/s]
#
# tqdm() Progress Bar Segments: 706it [05:34,  2.13it/s]
#
# tqdm() Progress Bar Segments: 707it [05:35,  2.12it/s]
#
# tqdm() Progress Bar Segments: 708it [05:35,  2.13it/s]
#
# tqdm() Progress Bar Segments: 709it [05:36,  2.11it/s]
#
# tqdm() Progress Bar Segments: 710it [05:36,  2.13it/s]
#
# tqdm() Progress Bar Segments: 711it [05:36,  2.14it/s]
#
# tqdm() Progress Bar Segments: 712it [05:37,  2.14it/s]
#
# tqdm() Progress Bar Segments: 713it [05:37,  2.15it/s]
#
# tqdm() Progress Bar Segments: 714it [05:38,  2.13it/s]
#
# tqdm() Progress Bar Segments: 715it [05:38,  2.13it/s]
#
# tqdm() Progress Bar Segments: 716it [05:39,  2.13it/s]
#
# tqdm() Progress Bar Segments: 717it [05:39,  2.13it/s]
#
# tqdm() Progress Bar Segments: 718it [05:40,  2.14it/s]
#
# tqdm() Progress Bar Segments: 719it [05:40,  2.17it/s]
#
# tqdm() Progress Bar Segments: 720it [05:41,  2.20it/s]
#
# tqdm() Progress Bar Segments: 721it [05:41,  2.22it/s]
#
# tqdm() Progress Bar Segments: 722it [05:42,  2.22it/s]
#
# tqdm() Progress Bar Segments: 723it [05:42,  2.23it/s]
#
# tqdm() Progress Bar Segments: 724it [05:42,  2.24it/s]
#
# tqdm() Progress Bar Segments: 725it [05:43,  2.23it/s]
#
# tqdm() Progress Bar Segments: 726it [05:43,  2.25it/s]
#
# tqdm() Progress Bar Segments: 727it [05:44,  2.25it/s]
#
# tqdm() Progress Bar Segments: 728it [05:44,  2.27it/s]
#
# tqdm() Progress Bar Segments: 729it [05:45,  2.28it/s]
#
# tqdm() Progress Bar Segments: 730it [05:45,  2.26it/s]
#
# tqdm() Progress Bar Segments: 731it [05:45,  2.27it/s]
#
# tqdm() Progress Bar Segments: 732it [05:46,  2.26it/s]
#
# tqdm() Progress Bar Segments: 733it [05:46,  2.28it/s]
#
# tqdm() Progress Bar Segments: 734it [05:47,  2.29it/s]
#
# tqdm() Progress Bar Segments: 735it [05:47,  2.28it/s]
#
# tqdm() Progress Bar Segments: 736it [05:48,  2.29it/s]
#
# tqdm() Progress Bar Segments: 737it [05:48,  2.26it/s]
#
# tqdm() Progress Bar Segments: 738it [05:49,  2.28it/s]
#
# tqdm() Progress Bar Segments: 739it [05:49,  2.26it/s]
#
# tqdm() Progress Bar Segments: 740it [05:49,  2.28it/s]
#
# tqdm() Progress Bar Segments: 741it [05:50,  2.28it/s]
#
# tqdm() Progress Bar Segments: 742it [05:50,  2.28it/s]
#
# tqdm() Progress Bar Segments: 743it [05:51,  2.29it/s]
#
# tqdm() Progress Bar Segments: 744it [05:51,  2.28it/s]
#
# tqdm() Progress Bar Segments: 745it [05:52,  2.27it/s]
#
# tqdm() Progress Bar Segments: 746it [05:52,  2.26it/s]
#
# tqdm() Progress Bar Segments: 747it [05:53,  2.29it/s]
#
# tqdm() Progress Bar Segments: 748it [05:53,  2.29it/s]
#
# tqdm() Progress Bar Segments: 749it [05:53,  2.29it/s]
#
# tqdm() Progress Bar Segments: 750it [05:54,  2.26it/s]
#
# tqdm() Progress Bar Segments: 751it [05:54,  2.28it/s]
#
# tqdm() Progress Bar Segments: 752it [05:55,  2.28it/s]
#
# tqdm() Progress Bar Segments: 753it [05:55,  2.28it/s]
#
# tqdm() Progress Bar Segments: 754it [05:56,  2.29it/s]
#
# tqdm() Progress Bar Segments: 755it [05:56,  2.28it/s]
#
# tqdm() Progress Bar Segments: 756it [05:56,  2.28it/s]
#
# tqdm() Progress Bar Segments: 757it [05:57,  2.27it/s]
#
# tqdm() Progress Bar Segments: 758it [05:57,  2.27it/s]
#
# tqdm() Progress Bar Segments: 759it [05:58,  2.27it/s]
#
# tqdm() Progress Bar Segments: 760it [05:58,  2.25it/s]
#
# tqdm() Progress Bar Segments: 761it [05:59,  2.27it/s]
#
# tqdm() Progress Bar Segments: 762it [05:59,  2.26it/s]
#
# tqdm() Progress Bar Segments: 763it [06:00,  2.26it/s]
#
# tqdm() Progress Bar Segments: 764it [06:00,  2.25it/s]
#
# tqdm() Progress Bar Segments: 765it [06:00,  2.27it/s]
#
# tqdm() Progress Bar Segments: 766it [06:01,  2.26it/s]
#
# tqdm() Progress Bar Segments: 767it [06:01,  2.27it/s]
#
# tqdm() Progress Bar Segments: 768it [06:02,  2.23it/s]
#
# tqdm() Progress Bar Segments: 769it [06:02,  2.24it/s]
#
# tqdm() Progress Bar Segments: 770it [06:03,  2.26it/s]
#
# tqdm() Progress Bar Segments: 771it [06:03,  2.26it/s]
#
# tqdm() Progress Bar Segments: 772it [06:04,  2.26it/s]
#
# tqdm() Progress Bar Segments: 773it [06:04,  2.27it/s]
#
# tqdm() Progress Bar Segments: 774it [06:04,  2.26it/s]
#
# tqdm() Progress Bar Segments: 775it [06:05,  2.26it/s]
#
# tqdm() Progress Bar Segments: 776it [06:05,  2.26it/s]
#
# tqdm() Progress Bar Segments: 777it [06:06,  2.26it/s]
#
# tqdm() Progress Bar Segments: 778it [06:06,  2.24it/s]
#
# tqdm() Progress Bar Segments: 779it [06:07,  2.26it/s]
#
# tqdm() Progress Bar Segments: 780it [06:07,  2.23it/s]
#
# tqdm() Progress Bar Segments: 781it [06:08,  2.26it/s]
#
# tqdm() Progress Bar Segments: 782it [06:08,  2.26it/s]
#
# tqdm() Progress Bar Segments: 783it [06:08,  2.24it/s]
#
# tqdm() Progress Bar Segments: 784it [06:09,  2.25it/s]
#
# tqdm() Progress Bar Segments: 785it [06:09,  2.25it/s]
#
# tqdm() Progress Bar Segments: 786it [06:10,  2.22it/s]
#
# tqdm() Progress Bar Segments: 787it [06:10,  2.19it/s]
#
# tqdm() Progress Bar Segments: 788it [06:11,  2.17it/s]
#
# tqdm() Progress Bar Segments: 789it [06:11,  2.16it/s]
#
# tqdm() Progress Bar Segments: 790it [06:12,  2.16it/s]
#
# tqdm() Progress Bar Segments: 791it [06:12,  2.15it/s]
#
# tqdm() Progress Bar Segments: 792it [06:13,  2.13it/s]
#
# tqdm() Progress Bar Segments: 793it [06:13,  2.13it/s]
#
# tqdm() Progress Bar Segments: 794it [06:14,  2.12it/s]
#
# tqdm() Progress Bar Segments: 795it [06:14,  2.11it/s]
#
# tqdm() Progress Bar Segments: 796it [06:15,  2.12it/s]
#
# tqdm() Progress Bar Segments: 797it [06:15,  2.10it/s]
#
# tqdm() Progress Bar Segments: 798it [06:15,  2.10it/s]
#
# tqdm() Progress Bar Segments: 799it [06:16,  2.12it/s]
#
# tqdm() Progress Bar Segments: 800it [06:16,  2.10it/s]
#
# tqdm() Progress Bar Segments: 801it [06:17,  2.11it/s]
#
# tqdm() Progress Bar Segments: 802it [06:17,  2.11it/s]
#
# tqdm() Progress Bar Segments: 803it [06:18,  2.11it/s]
#
# tqdm() Progress Bar Segments: 804it [06:18,  2.11it/s]
#
# tqdm() Progress Bar Segments: 805it [06:19,  2.10it/s]
#
# tqdm() Progress Bar Segments: 806it [06:19,  2.10it/s]
#
# tqdm() Progress Bar Segments: 807it [06:20,  2.11it/s]
#
# tqdm() Progress Bar Segments: 808it [06:20,  2.11it/s]
#
# tqdm() Progress Bar Segments: 809it [06:21,  2.11it/s]
#
# tqdm() Progress Bar Segments: 810it [06:21,  2.12it/s]
#
# tqdm() Progress Bar Segments: 811it [06:22,  2.11it/s]
#
# tqdm() Progress Bar Segments: 812it [06:22,  2.11it/s]
#
# tqdm() Progress Bar Segments: 813it [06:23,  2.10it/s]
#
# tqdm() Progress Bar Segments: 814it [06:23,  2.10it/s]
#
# tqdm() Progress Bar Segments: 815it [06:24,  2.10it/s]
#
# tqdm() Progress Bar Segments: 816it [06:24,  2.12it/s]
#
# tqdm() Progress Bar Segments: 817it [06:24,  2.14it/s]
#
# tqdm() Progress Bar Segments: 818it [06:25,  2.13it/s]
#
# tqdm() Progress Bar Segments: 819it [06:25,  2.11it/s]
#
# tqdm() Progress Bar Segments: 820it [06:26,  2.13it/s]
#
# tqdm() Progress Bar Segments: 821it [06:26,  2.13it/s]
#
# tqdm() Progress Bar Segments: 822it [06:27,  2.13it/s]
#
# tqdm() Progress Bar Segments: 823it [06:27,  2.14it/s]
#
# tqdm() Progress Bar Segments: 824it [06:28,  2.12it/s]
#
# tqdm() Progress Bar Segments: 825it [06:28,  2.13it/s]
#
# tqdm() Progress Bar Segments: 826it [06:29,  2.10it/s]
#
# tqdm() Progress Bar Segments: 827it [06:29,  2.10it/s]
#
# tqdm() Progress Bar Segments: 828it [06:30,  2.10it/s]
#
# tqdm() Progress Bar Segments: 829it [06:30,  2.11it/s]
#
# tqdm() Progress Bar Segments: 830it [06:31,  2.11it/s]
#
# tqdm() Progress Bar Segments: 831it [06:31,  2.12it/s]
#
# tqdm() Progress Bar Segments: 832it [06:32,  2.13it/s]
#
# tqdm() Progress Bar Segments: 833it [06:32,  2.12it/s]
#
# tqdm() Progress Bar Segments: 834it [06:32,  2.12it/s]
#
# tqdm() Progress Bar Segments: 835it [06:33,  2.11it/s]
#
# tqdm() Progress Bar Segments: 836it [06:33,  2.11it/s]
#
# tqdm() Progress Bar Segments: 837it [06:34,  2.13it/s]
#
# tqdm() Progress Bar Segments: 838it [06:34,  2.12it/s]
#
# tqdm() Progress Bar Segments: 839it [06:35,  2.11it/s]
#
# tqdm() Progress Bar Segments: 840it [06:35,  2.13it/s]
#
# tqdm() Progress Bar Segments: 841it [06:36,  2.11it/s]
#
# tqdm() Progress Bar Segments: 842it [06:36,  2.12it/s]
#
# tqdm() Progress Bar Segments: 843it [06:37,  2.11it/s]
#
# tqdm() Progress Bar Segments: 844it [06:37,  2.11it/s]
#
# tqdm() Progress Bar Segments: 845it [06:38,  2.10it/s]
#
# tqdm() Progress Bar Segments: 846it [06:38,  2.11it/s]
#
# tqdm() Progress Bar Segments: 847it [06:39,  2.11it/s]
#
# tqdm() Progress Bar Segments: 848it [06:39,  2.09it/s]
#
# tqdm() Progress Bar Segments: 849it [06:40,  2.12it/s]
#
# tqdm() Progress Bar Segments: 850it [06:40,  2.15it/s]
#
# tqdm() Progress Bar Segments: 851it [06:40,  2.19it/s]
#
# tqdm() Progress Bar Segments: 852it [06:41,  2.22it/s]
#
# tqdm() Progress Bar Segments: 853it [06:41,  2.25it/s]
#
# tqdm() Progress Bar Segments: 854it [06:42,  2.26it/s]
#
# tqdm() Progress Bar Segments: 855it [06:42,  2.25it/s]
#
# tqdm() Progress Bar Segments: 856it [06:43,  2.27it/s]
#
# tqdm() Progress Bar Segments: 857it [06:43,  2.28it/s]
#
# tqdm() Progress Bar Segments: 858it [06:44,  2.27it/s]
#
# tqdm() Progress Bar Segments: 859it [06:44,  2.24it/s]
#
# tqdm() Progress Bar Segments: 860it [06:44,  2.25it/s]
#
# tqdm() Progress Bar Segments: 861it [06:45,  2.25it/s]
#
# tqdm() Progress Bar Segments: 862it [06:45,  2.25it/s]
#
# tqdm() Progress Bar Segments: 863it [06:46,  2.27it/s]
#
# tqdm() Progress Bar Segments: 864it [06:46,  2.26it/s]
#
# tqdm() Progress Bar Segments: 865it [06:47,  2.29it/s]
#
# tqdm() Progress Bar Segments: 866it [06:47,  2.28it/s]
#
# tqdm() Progress Bar Segments: 867it [06:47,  2.31it/s]
#
# tqdm() Progress Bar Segments: 868it [06:48,  2.28it/s]
#
# tqdm() Progress Bar Segments: 869it [06:48,  2.26it/s]
#
# tqdm() Progress Bar Segments: 870it [06:49,  2.27it/s]
#
# tqdm() Progress Bar Segments: 871it [06:49,  2.26it/s]
#
# tqdm() Progress Bar Segments: 872it [06:50,  2.26it/s]
#
# tqdm() Progress Bar Segments: 873it [06:50,  2.28it/s]
#
# tqdm() Progress Bar Segments: 874it [06:51,  2.29it/s]
#
# tqdm() Progress Bar Segments: 875it [06:51,  2.27it/s]
#
# tqdm() Progress Bar Segments: 876it [06:51,  2.29it/s]
#
# tqdm() Progress Bar Segments: 877it [06:52,  2.29it/s]
#
# tqdm() Progress Bar Segments: 878it [06:52,  2.27it/s]
#
# tqdm() Progress Bar Segments: 879it [06:53,  1.98it/s]
#
# tqdm() Progress Bar Segments: 880it [06:53,  2.05it/s]
#
# tqdm() Progress Bar Segments: 881it [06:54,  2.09it/s]
#
# tqdm() Progress Bar Segments: 882it [06:54,  2.14it/s]
#
# tqdm() Progress Bar Segments: 883it [06:55,  2.18it/s]
#
# tqdm() Progress Bar Segments: 884it [06:55,  2.19it/s]
#
# tqdm() Progress Bar Segments: 885it [06:56,  2.22it/s]
#
# tqdm() Progress Bar Segments: 886it [06:56,  2.25it/s]
#
# tqdm() Progress Bar Segments: 887it [06:57,  2.27it/s]
#
# tqdm() Progress Bar Segments: 888it [06:57,  2.27it/s]
#
# tqdm() Progress Bar Segments: 889it [06:57,  2.27it/s]
#
# tqdm() Progress Bar Segments: 890it [06:58,  2.26it/s]
#
# tqdm() Progress Bar Segments: 891it [06:58,  2.24it/s]
#
# tqdm() Progress Bar Segments: 892it [06:59,  2.25it/s]
#
# tqdm() Progress Bar Segments: 893it [06:59,  2.24it/s]
#
# tqdm() Progress Bar Segments: 894it [07:00,  2.24it/s]
#
# tqdm() Progress Bar Segments: 895it [07:00,  2.26it/s]
#
# tqdm() Progress Bar Segments: 896it [07:01,  2.27it/s]
#
# tqdm() Progress Bar Segments: 897it [07:01,  2.27it/s]
#
# tqdm() Progress Bar Segments: 898it [07:01,  2.27it/s]
#
# tqdm() Progress Bar Segments: 899it [07:02,  2.28it/s]
#
# tqdm() Progress Bar Segments: 900it [07:02,  2.28it/s]
#
# tqdm() Progress Bar Segments: 901it [07:03,  2.29it/s]
#
# tqdm() Progress Bar Segments: 902it [07:03,  2.28it/s]
#
# tqdm() Progress Bar Segments: 903it [07:04,  2.28it/s]
#
# tqdm() Progress Bar Segments: 904it [07:04,  2.29it/s]
#
# tqdm() Progress Bar Segments: 905it [07:04,  2.28it/s]
#
# tqdm() Progress Bar Segments: 906it [07:05,  2.28it/s]
#
# tqdm() Progress Bar Segments: 907it [07:05,  2.27it/s]
#
# tqdm() Progress Bar Segments: 908it [07:06,  2.27it/s]
#
# tqdm() Progress Bar Segments: 909it [07:06,  2.29it/s]
#
# tqdm() Progress Bar Segments: 910it [07:07,  2.27it/s]
#
# tqdm() Progress Bar Segments: 911it [07:07,  2.27it/s]
#
# tqdm() Progress Bar Segments: 912it [07:08,  2.27it/s]
#
# tqdm() Progress Bar Segments: 913it [07:08,  2.28it/s]
#
# tqdm() Progress Bar Segments: 914it [07:08,  2.27it/s]
#
# tqdm() Progress Bar Segments: 915it [07:09,  2.27it/s]
#
# tqdm() Progress Bar Segments: 916it [07:09,  2.28it/s]
#
# tqdm() Progress Bar Segments: 917it [07:10,  2.23it/s]
#
# tqdm() Progress Bar Segments: 918it [07:10,  2.18it/s]
#
# tqdm() Progress Bar Segments: 919it [07:11,  2.17it/s]
#
# tqdm() Progress Bar Segments: 920it [07:11,  2.15it/s]
#
# tqdm() Progress Bar Segments: 921it [07:12,  2.13it/s]
#
# tqdm() Progress Bar Segments: 922it [07:12,  2.14it/s]
#
# tqdm() Progress Bar Segments: 923it [07:13,  2.12it/s]
#
# tqdm() Progress Bar Segments: 924it [07:13,  2.12it/s]
#
# tqdm() Progress Bar Segments: 925it [07:14,  2.12it/s]
#
# tqdm() Progress Bar Segments: 926it [07:14,  2.13it/s]
#
# tqdm() Progress Bar Segments: 927it [07:15,  2.13it/s]
#
# tqdm() Progress Bar Files: 1it [08:17, 497.71s/it]
# RAM Total : 13298.6
# RAM Used : 5496.6
# Wait a moment, the threads are processing 0 images, it may be delayed depending on the size or quantity of the images!
# 0it [00:00, ?it/s]
# tqdm() Progress Bar Models:   0%|          | 0/1 [08:30<?, ?it/s]

# %%
list_iou()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-bcaef3e5f9f7> in <module>()
# ----> 1 list_iou()
#
# NameError: name 'list_iou' is not defined

# %%
location_drive='/content/drive/MyDrive/datasets/dataset_anette/data_labelme/'
model_name = "Xception"
model = load_model(location_drive+"model/"+model_name+"_transfer_learning_adagrad.h5")

# %%
model.summary()

# %%
model.layers.pop(0)

# %%
newInput = tf.keras.layers.Input(batch_shape=(0,199,199,3))
op = model(newInput)

# %%
newModel = tf.keras.Model(newInput,op)

# %%
newModel.summary()

# %%
base_model = tf.keras.applications.Xception(
    weights=location_drive+"model/"+model_name+"_transfer_learning_adagrad.h5",  # Load weights pre-trained on ImageNet.
    input_shape=(150, 150, 3),
    include_top=False)
